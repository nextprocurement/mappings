# %%
import pandas as pd

file_path = "data/outsiders_2021.parquet"

pd.read_parquet(file_path, engine='fastparquet')
# Out:
#                                                  summary  \
# 0      Id licitación: BE-2015-2059; Importe: 59999.00...
# 1      Id licitación: BE-2015-2854; Importe: 309112.9...
# 2      Id licitación: BE-2015-2852; Importe: 414141.8...
# 3      Id licitación: BE-2015-2855; Importe: 237930.9...
# 4      Id licitación: BE-2015-2853; Importe: 242732.9...
# ...                                                  ...
# 64015  Id licitación: 6012100361;Órgano de Contrataci...
# 64016  Id licitación: 6012100356;Órgano de Contrataci...
# 64017  Id licitación: 76/2021;Órgano de Contratación:...
# 64018  Id licitación: A/OBR-019760/2021;Órgano de Con...
# 64019  Id licitación: 4660; Órgano de Contratación: ...
#
#                                                    title  \
# 0      Servei de dinamització de l¿equipament cívic F...
# 1      Servei de monitoratge de les activitats que es...
# 2      Servei de monitoratge de les activitats que es...
# 3      Servei de monitoratge de les activitats que es...
# 4      Servei de monitoratge de les activitats que es...
# ...                                                  ...
# 64015  Acuerdo Marco para los servicios de realizació...
# 64016  Servicio de apoyo al mantenimiento de instalac...
# 64017                     VI Encuesta seroepidemiologica
# 64018  A/OBR-019760/2021 Convocatoria Obras CEIP Párr...
# 64019  Servicios para el apoyo en la realización de t...
#
#                                updated Número de Expediente Estado  \
# 0     2021-04-22 14:11:48.528000+00:00         BE-2015-2059    RES
# 1     2021-04-22 08:11:26.837000+00:00         BE-2015-2854    RES
# 2     2021-04-22 08:11:27.336000+00:00         BE-2015-2852    RES
# 3     2021-04-22 08:11:26.206000+00:00         BE-2015-2855    RES
# 4     2021-04-22 08:26:51.413000+00:00         BE-2015-2853    RES
# ...                                ...                  ...    ...
# 64015 2021-12-31 07:26:16.532000+00:00           6012100361    PUB
# 64016 2021-12-31 06:41:13.045000+00:00           6012100356    PUB
# 64017 2021-12-31 05:26:14.262000+00:00              76/2021    PUB
# 64018 2021-12-31 05:26:13.941000+00:00    A/OBR-019760/2021     EV
# 64019 2021-12-31 04:26:24.530000+00:00                 4660    PUB
#
#                                                   Nombre  \
# 0               Departament de Benestar Social I Família
# 1               Departament de Benestar Social I Família
# 2               Departament de Benestar Social I Família
# 3               Departament de Benestar Social I Família
# 4               Departament de Benestar Social I Família
# ...                                                  ...
# 64015           Empresa Pública de Metro de Madrid, S.A.
# 64016           Empresa Pública de Metro de Madrid, S.A.
# 64017                              Consejería de Sanidad
# 64018  Consejería de Administración Local y Digitaliz...
# 64019                                   Director-Gerente
#
#                                  Ubicación orgánica  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 64015  Consejería de Transportes e Infraestructuras
# 64016  Consejería de Transportes e Infraestructuras
# 64017                                          None
# 64018                                          None
# 64019                                        LANTIK
#
#                                      Objeto del Contrato  Tipo de Contrato  \
# 0      Servei de dinamització de l¿equipament cívic F...               2.0
# 1      Servei de monitoratge de les activitats que es...               2.0
# 2      Servei de monitoratge de les activitats que es...               2.0
# 3      Servei de monitoratge de les activitats que es...               2.0
# 4      Servei de monitoratge de les activitats que es...               2.0
# ...                                                  ...               ...
# 64015  Acuerdo Marco para los servicios de realizació...               2.0
# 64016  Servicio de apoyo al mantenimiento de instalac...               2.0
# 64017  Trabajo de campo de la VI Encuesta seroepidemi...               2.0
# 64018  Obras de mejora, acondicionamiento, reparación...               3.0
# 64019  Servicios para el apoyo en la realización de t...               2.0
#
#        Valor estimado del contrato  ...  Presentación de Solicitudes (Hora)  \
# 0                         59999.00  ...                                None
# 1                        803693.72  ...                                None
# 2                       1076768.82  ...                                None
# 3                        618620.50  ...                                None
# 4                        631105.64  ...                                None
# ...                            ...  ...                                 ...
# 64015                    423671.80  ...                                None
# 64016                    471000.00  ...                                None
# 64017                    140000.00  ...                                None
# 64018                    148992.02  ...                                None
# 64019                   1884000.00  ...                                None
#
#                                URL perfil de contratante         ID    Lote  \
# 0                                                   None  A09002972  [None]
# 1                                                   None  A09002972  [None]
# 2                                                   None  A09002972  [None]
# 3                                                   None  A09002972  [None]
# 4                                                   None  A09002972  [None]
# ...                                                  ...        ...     ...
# 64015  http://www.madrid.org/cs/Satellite?cid=1204201...       None  [None]
# 64016  http://www.madrid.org/cs/Satellite?cid=1204201...       None  [None]
# 64017  http://www.madrid.org/cs/Satellite?cid=1204201...       None  [None]
# 64018  http://www.madrid.org/cs/Satellite?cid=1204201...       None  [None]
# 64019                                               None       None  [None]
#
#          Presentación de Oferta  \
# 0     2015-06-26 02:00:00+00:00
# 1     2015-07-30 02:00:00+00:00
# 2     2015-07-30 02:00:00+00:00
# 3     2015-07-28 02:00:00+00:00
# 4     2015-07-28 02:00:00+00:00
# ...                         ...
# 64015 2022-01-25 12:00:00+00:00
# 64016 2022-01-28 12:00:00+00:00
# 64017 2022-01-17 23:59:00+00:00
# 64018                       NaT
# 64019 2022-01-27 12:00:00+00:00
#
#       ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 64015                                               None
# 64016                                               None
# 64017                                               None
# 64018                                               None
# 64019                                               None
#
#                              domain  \
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ...                             ...
# 64015                www.madrid.org
# 64016                www.madrid.org
# 64017                www.madrid.org
# 64018                www.madrid.org
# 64019  www.contratacion.euskadi.eus
#
#                                                file name  \
# 0      PlataformasAgregadasSinMenores_20210120_030025...
# 1      PlataformasAgregadasSinMenores_20210219_030030...
# 2      PlataformasAgregadasSinMenores_20210219_030030...
# 3      PlataformasAgregadasSinMenores_20210219_030030...
# 4      PlataformasAgregadasSinMenores_20210219_030030...
# ...                                                  ...
# 64015                                               None
# 64016                                               None
# 64017                                               None
# 64018                                               None
# 64019                                               None
#
#                                                    entry  \
# 0      https://contrataciondelestado.es/sindicacion/P...
# 1      https://contrataciondelestado.es/sindicacion/P...
# 2      https://contrataciondelestado.es/sindicacion/P...
# 3      https://contrataciondelestado.es/sindicacion/P...
# 4      https://contrataciondelestado.es/sindicacion/P...
# ...                                                  ...
# 64015                                               None
# 64016                                               None
# 64017                                               None
# 64018                                               None
# 64019                                               None
#
#                    deleted_on
# 0     2021-01-18 23:11:01.869
# 1     2021-02-17 23:11:08.608
# 2     2021-02-17 23:11:08.510
# 3     2021-02-17 23:11:09.928
# 4     2021-02-17 23:11:09.660
# ...                       ...
# 64015                     NaT
# 64016                     NaT
# 64017                     NaT
# 64018                     NaT
# 64019                     NaT
#
# [64020 rows x 43 columns]

# %%
import pandas as pd

file_path = "data/outsiders_2021.parquet"

pd.read_parquet(file_path, engine='pyarrow')
# Out:
#                                                  summary  \
# 0      Id licitación: BE-2015-2059; Importe: 59999.00...
# 1      Id licitación: BE-2015-2854; Importe: 309112.9...
# 2      Id licitación: BE-2015-2852; Importe: 414141.8...
# 3      Id licitación: BE-2015-2855; Importe: 237930.9...
# 4      Id licitación: BE-2015-2853; Importe: 242732.9...
# ...                                                  ...
# 64015  Id licitación: 6012100361;Órgano de Contrataci...
# 64016  Id licitación: 6012100356;Órgano de Contrataci...
# 64017  Id licitación: 76/2021;Órgano de Contratación:...
# 64018  Id licitación: A/OBR-019760/2021;Órgano de Con...
# 64019  Id licitación: 4660; Órgano de Contratación: ...
#
#                                                    title  \
# 0      Servei de dinamització de l¿equipament cívic F...
# 1      Servei de monitoratge de les activitats que es...
# 2      Servei de monitoratge de les activitats que es...
# 3      Servei de monitoratge de les activitats que es...
# 4      Servei de monitoratge de les activitats que es...
# ...                                                  ...
# 64015  Acuerdo Marco para los servicios de realizació...
# 64016  Servicio de apoyo al mantenimiento de instalac...
# 64017                     VI Encuesta seroepidemiologica
# 64018  A/OBR-019760/2021 Convocatoria Obras CEIP Párr...
# 64019  Servicios para el apoyo en la realización de t...
#
#                                updated Número de Expediente Estado  \
# 0     2021-04-22 14:11:48.528000+00:00         BE-2015-2059    RES
# 1     2021-04-22 08:11:26.837000+00:00         BE-2015-2854    RES
# 2     2021-04-22 08:11:27.336000+00:00         BE-2015-2852    RES
# 3     2021-04-22 08:11:26.206000+00:00         BE-2015-2855    RES
# 4     2021-04-22 08:26:51.413000+00:00         BE-2015-2853    RES
# ...                                ...                  ...    ...
# 64015 2021-12-31 07:26:16.532000+00:00           6012100361    PUB
# 64016 2021-12-31 06:41:13.045000+00:00           6012100356    PUB
# 64017 2021-12-31 05:26:14.262000+00:00              76/2021    PUB
# 64018 2021-12-31 05:26:13.941000+00:00    A/OBR-019760/2021     EV
# 64019 2021-12-31 04:26:24.530000+00:00                 4660    PUB
#
#                                                   Nombre  \
# 0               Departament de Benestar Social I Família
# 1               Departament de Benestar Social I Família
# 2               Departament de Benestar Social I Família
# 3               Departament de Benestar Social I Família
# 4               Departament de Benestar Social I Família
# ...                                                  ...
# 64015           Empresa Pública de Metro de Madrid, S.A.
# 64016           Empresa Pública de Metro de Madrid, S.A.
# 64017                              Consejería de Sanidad
# 64018  Consejería de Administración Local y Digitaliz...
# 64019                                   Director-Gerente
#
#                                  Ubicación orgánica  \
# 0                                              <NA>
# 1                                              <NA>
# 2                                              <NA>
# 3                                              <NA>
# 4                                              <NA>
# ...                                             ...
# 64015  Consejería de Transportes e Infraestructuras
# 64016  Consejería de Transportes e Infraestructuras
# 64017                                          <NA>
# 64018                                          <NA>
# 64019                                        LANTIK
#
#                                      Objeto del Contrato  Tipo de Contrato  \
# 0      Servei de dinamització de l¿equipament cívic F...               2.0
# 1      Servei de monitoratge de les activitats que es...               2.0
# 2      Servei de monitoratge de les activitats que es...               2.0
# 3      Servei de monitoratge de les activitats que es...               2.0
# 4      Servei de monitoratge de les activitats que es...               2.0
# ...                                                  ...               ...
# 64015  Acuerdo Marco para los servicios de realizació...               2.0
# 64016  Servicio de apoyo al mantenimiento de instalac...               2.0
# 64017  Trabajo de campo de la VI Encuesta seroepidemi...               2.0
# 64018  Obras de mejora, acondicionamiento, reparación...               3.0
# 64019  Servicios para el apoyo en la realización de t...               2.0
#
#        Valor estimado del contrato  ...  Presentación de Solicitudes (Hora)  \
# 0                         59999.00  ...                                <NA>
# 1                        803693.72  ...                                <NA>
# 2                       1076768.82  ...                                <NA>
# 3                        618620.50  ...                                <NA>
# 4                        631105.64  ...                                <NA>
# ...                            ...  ...                                 ...
# 64015                    423671.80  ...                                <NA>
# 64016                    471000.00  ...                                <NA>
# 64017                    140000.00  ...                                <NA>
# 64018                    148992.02  ...                                <NA>
# 64019                   1884000.00  ...                                <NA>
#
#                                URL perfil de contratante         ID   Lote  \
# 0                                                   <NA>  A09002972  [nan]
# 1                                                   <NA>  A09002972  [nan]
# 2                                                   <NA>  A09002972  [nan]
# 3                                                   <NA>  A09002972  [nan]
# 4                                                   <NA>  A09002972  [nan]
# ...                                                  ...        ...    ...
# 64015  http://www.madrid.org/cs/Satellite?cid=1204201...       <NA>  [nan]
# 64016  http://www.madrid.org/cs/Satellite?cid=1204201...       <NA>  [nan]
# 64017  http://www.madrid.org/cs/Satellite?cid=1204201...       <NA>  [nan]
# 64018  http://www.madrid.org/cs/Satellite?cid=1204201...       <NA>  [nan]
# 64019                                               <NA>       <NA>  [nan]
#
#          Presentación de Oferta  \
# 0     2015-06-26 02:00:00+00:00
# 1     2015-07-30 02:00:00+00:00
# 2     2015-07-30 02:00:00+00:00
# 3     2015-07-28 02:00:00+00:00
# 4     2015-07-28 02:00:00+00:00
# ...                         ...
# 64015 2022-01-25 12:00:00+00:00
# 64016 2022-01-28 12:00:00+00:00
# 64017 2022-01-17 23:59:00+00:00
# 64018                       NaT
# 64019 2022-01-27 12:00:00+00:00
#
#       ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 0                                                   <NA>
# 1                                                   <NA>
# 2                                                   <NA>
# 3                                                   <NA>
# 4                                                   <NA>
# ...                                                  ...
# 64015                                               <NA>
# 64016                                               <NA>
# 64017                                               <NA>
# 64018                                               <NA>
# 64019                                               <NA>
#
#                              domain  \
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ...                             ...
# 64015                www.madrid.org
# 64016                www.madrid.org
# 64017                www.madrid.org
# 64018                www.madrid.org
# 64019  www.contratacion.euskadi.eus
#
#                                                file name  \
# 0      PlataformasAgregadasSinMenores_20210120_030025...
# 1      PlataformasAgregadasSinMenores_20210219_030030...
# 2      PlataformasAgregadasSinMenores_20210219_030030...
# 3      PlataformasAgregadasSinMenores_20210219_030030...
# 4      PlataformasAgregadasSinMenores_20210219_030030...
# ...                                                  ...
# 64015                                               None
# 64016                                               None
# 64017                                               None
# 64018                                               None
# 64019                                               None
#
#                                                    entry  \
# 0      https://contrataciondelestado.es/sindicacion/P...
# 1      https://contrataciondelestado.es/sindicacion/P...
# 2      https://contrataciondelestado.es/sindicacion/P...
# 3      https://contrataciondelestado.es/sindicacion/P...
# 4      https://contrataciondelestado.es/sindicacion/P...
# ...                                                  ...
# 64015                                               None
# 64016                                               None
# 64017                                               None
# 64018                                               None
# 64019                                               None
#
#                             deleted_on
# 0     2021-01-19 00:11:01.869000+01:00
# 1     2021-02-18 00:11:08.608000+01:00
# 2     2021-02-18 00:11:08.510000+01:00
# 3     2021-02-18 00:11:09.928000+01:00
# 4     2021-02-18 00:11:09.660000+01:00
# ...                                ...
# 64015                              NaT
# 64016                              NaT
# 64017                              NaT
# 64018                              NaT
# 64019                              NaT
#
# [64020 rows x 43 columns]
